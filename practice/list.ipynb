# %%
##1. common between two lists

list1 = [1,4,3,6,9]
list2 = [5,4,0]

common_element = []
for i in list1:
    for j in list2:
        if i==j:
            common_element.append(i)
print(common_element)
# Out:
# [4]

# %%
##2.
